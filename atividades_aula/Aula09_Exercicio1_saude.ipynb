# %%
import testaula09 as t

# %%
t.compra()
# Out:
# qual o valor do produto: 50
# Quanto dinheiro tem na sua carteira: 40
# Quanto tem no cartão: 10
# True
# Não tem dinheiro suficiente
# Não tem crédito no seu cartão!
# Tem a possibilidade de pagar usando o dinheiro e cartão.

# %%
t.desviop()
# Out:
# Informe a notas de 0 a 10 separadas por espaços: 4 5 6 7 10
# A média das 5 notas é 6.4
# O Desvio Padrão das notas 5 notas é 2.30

# %%
t.par_impar()
# Out:
# informe um número:
# Ops, parece que você não digitou um número válido!! tente novamente
# informe um número: ffd
# Ops, parece que você não digitou um número válido!! tente novamente
# informe um número: 1
# Parabéns 1.0 é um número válido
# o número 1.0 é impar

# %%
t.numeros_aleatorios()
# Out:
# Adivinhe o número de 0 a 100: 60
# Tente um número menor
# Adivinhe o número de 0 a 100: 50
# Tente um número maior.
# Adivinhe o número de 0 a 100: 55
# Tente um número maior.
# Adivinhe o número de 0 a 100: 57
# Parabéns! Você acertou em 4 tentativas.

# %%
t.credencial()
# Out:
# Digite seu usuario: aluno
# Digite sua senha: aluno
# credenciais inválidas! Tente novamente

# %%
t.frequencia_notas()
# Out:
# Digite sua nota de 0 a 100: 75
# Digite sua frequência de 0 a 100: 50
# Aprovado!
# Reprovado por frequência
