# %% [markdown]
# #**Marketing - Projeto Final**
#
# Escola: SoulCode Academy
#
# Curso: PreparaTech - AD4
#
# Assunto: Marketing - Projeto Final
#
# **Alunos:**
# * Edson Miranda
# * Fabio Jacinto
# * Jessica Hirota
# * Vitor Kawasaki

# %% [markdown]
# #Importando Pandas

# %%
#importando a biblioteca
import pandas as pd

# %% [markdown]
# ##Limitando colunas em DataFrame

# %%
# configurando a quantidade de colunas para aparecer em um dataframe
pd.set_option('display.max_columns',100)

# %% [markdown]
# #**1 - Extração de Dados**

# %% [markdown]
# * Tipos de separador: Vírgula (,) - Ponto e vírgula (;) - Tabulação (\t) - Espaço em branco ( )
# * Enconding: UTF-8, ISO-8859-1, UTF-16, UTF-32, ASCII

# %% [markdown]
# https://www.kaggle.com/datasets/manishabhatt22/marketing-campaign-performance-dataset

# %%
# o arquivo está no drive do grupo na pasta campanha_marketing01
df = pd.read_csv('/content/marketing_campaign_dataset.csv',
                 sep=',',
                 encoding='ISO-8859-1')

# %% [markdown]
# ##1.1 - Verificação de Dados

# %%
# Verificação de extração dos dados
# Mostra sempre as 5 primeiras linhas do dataframe e as 5 últimas linhas.
# Dentro da df é mostrado a quantidade de rows(linhas) × columns(colunas)
df
# Out:
#         Campaign_ID              Company Campaign_Type Target_Audience  \
# 0                 1  Innovate Industries         Email       Men 18-24
# 1                 2       NexGen Systems         Email     Women 35-44
# 2                 3    Alpha Innovations    Influencer       Men 25-34
# 3                 4   DataTech Solutions       Display        All Ages
# 4                 5       NexGen Systems         Email       Men 25-34
# ...             ...                  ...           ...             ...
# 199995       199996             TechCorp       Display        All Ages
# 199996       199997   DataTech Solutions         Email       Men 25-34
# 199997       199998   DataTech Solutions  Social Media       Men 18-24
# 199998       199999  Innovate Industries    Influencer        All Ages
# 199999       200000  Innovate Industries  Social Media     Women 35-44
#
#        Duration Channel_Used  Conversion_Rate Acquisition_Cost   ROI  \
# 0       30 days   Google Ads             0.04       $16,174.00  6.29
# 1       60 days   Google Ads             0.12       $11,566.00  5.61
# 2       30 days      YouTube             0.07       $10,200.00  7.18
# 3       60 days      YouTube             0.11       $12,724.00  5.55
# 4       15 days      YouTube             0.05       $16,452.00  6.50
# ...         ...          ...              ...              ...   ...
# 199995  30 days   Google Ads             0.06       $18,365.00  2.84
# 199996  15 days     Facebook             0.02        $8,168.00  4.14
# 199997  45 days      Website             0.05       $13,397.00  3.25
# 199998  30 days      YouTube             0.10       $18,508.00  3.86
# 199999  45 days   Google Ads             0.01       $13,835.00  6.64
#
#            Location  Language  Clicks  Impressions  Engagement_Score  \
# 0           Chicago   Spanish     506         1922                 6
# 1          New York    German     116         7523                 7
# 2       Los Angeles    French     584         7698                 1
# 3             Miami  Mandarin     217         1820                 7
# 4       Los Angeles  Mandarin     379         4201                 3
# ...             ...       ...     ...          ...               ...
# 199995      Chicago    German     858         5988                 1
# 199996      Chicago   Spanish     228         3068                 7
# 199997     New York  Mandarin     723         9548                 3
# 199998      Houston    French     528         2763                 1
# 199999      Chicago   Spanish     924         7287                 8
#
#            Customer_Segment        Date
# 0         Health & Wellness  2021-01-01
# 1              Fashionistas  2021-01-02
# 2       Outdoor Adventurers  2021-01-03
# 3         Health & Wellness  2021-01-04
# 4         Health & Wellness  2021-01-05
# ...                     ...         ...
# 199995     Tech Enthusiasts  2021-12-07
# 199996              Foodies  2021-12-08
# 199997     Tech Enthusiasts  2021-12-09
# 199998              Foodies  2021-12-10
# 199999     Tech Enthusiasts  2021-12-11
#
# [200000 rows x 16 columns]

# %%
# as 5 primeiras linhas
df.head()
# Out:
#    Campaign_ID              Company Campaign_Type Target_Audience Duration  \
# 0            1  Innovate Industries         Email       Men 18-24  30 days
# 1            2       NexGen Systems         Email     Women 35-44  60 days
# 2            3    Alpha Innovations    Influencer       Men 25-34  30 days
# 3            4   DataTech Solutions       Display        All Ages  60 days
# 4            5       NexGen Systems         Email       Men 25-34  15 days
#
#   Channel_Used  Conversion_Rate Acquisition_Cost   ROI     Location  Language  \
# 0   Google Ads             0.04       $16,174.00  6.29      Chicago   Spanish
# 1   Google Ads             0.12       $11,566.00  5.61     New York    German
# 2      YouTube             0.07       $10,200.00  7.18  Los Angeles    French
# 3      YouTube             0.11       $12,724.00  5.55        Miami  Mandarin
# 4      YouTube             0.05       $16,452.00  6.50  Los Angeles  Mandarin
#
#    Clicks  Impressions  Engagement_Score     Customer_Segment        Date
# 0     506         1922                 6    Health & Wellness  2021-01-01
# 1     116         7523                 7         Fashionistas  2021-01-02
# 2     584         7698                 1  Outdoor Adventurers  2021-01-03
# 3     217         1820                 7    Health & Wellness  2021-01-04
# 4     379         4201                 3    Health & Wellness  2021-01-05

# %%
# Visualizando as últimas posições do dataframe
# Mostra apenas as 5 últimas linhas
df.tail()
# Out:
#         Campaign_ID              Company Campaign_Type Target_Audience  \
# 199995       199996             TechCorp       Display        All Ages
# 199996       199997   DataTech Solutions         Email       Men 25-34
# 199997       199998   DataTech Solutions  Social Media       Men 18-24
# 199998       199999  Innovate Industries    Influencer        All Ages
# 199999       200000  Innovate Industries  Social Media     Women 35-44
#
#        Duration Channel_Used  Conversion_Rate Acquisition_Cost   ROI  \
# 199995  30 days   Google Ads             0.06       $18,365.00  2.84
# 199996  15 days     Facebook             0.02        $8,168.00  4.14
# 199997  45 days      Website             0.05       $13,397.00  3.25
# 199998  30 days      YouTube             0.10       $18,508.00  3.86
# 199999  45 days   Google Ads             0.01       $13,835.00  6.64
#
#         Location  Language  Clicks  Impressions  Engagement_Score  \
# 199995   Chicago    German     858         5988                 1
# 199996   Chicago   Spanish     228         3068                 7
# 199997  New York  Mandarin     723         9548                 3
# 199998   Houston    French     528         2763                 1
# 199999   Chicago   Spanish     924         7287                 8
#
#         Customer_Segment        Date
# 199995  Tech Enthusiasts  2021-12-07
# 199996           Foodies  2021-12-08
# 199997  Tech Enthusiasts  2021-12-09
# 199998           Foodies  2021-12-10
# 199999  Tech Enthusiasts  2021-12-11

# %%
# Visualização do dataframe de forma aleatória para verificação de dados
df.sample(5)
# Out:
#         Campaign_ID              Company Campaign_Type Target_Audience  \
# 31873         31874    Alpha Innovations        Search       Men 18-24
# 186549       186550    Alpha Innovations    Influencer        All Ages
# 98564         98565             TechCorp    Influencer        All Ages
# 132398       132399       NexGen Systems         Email       Men 18-24
# 158433       158434  Innovate Industries    Influencer       Men 18-24
#
#        Duration Channel_Used  Conversion_Rate Acquisition_Cost   ROI  \
# 31873   60 days   Google Ads             0.01       $12,028.00  7.37
# 186549  30 days   Google Ads             0.14        $5,391.00  6.57
# 98564   60 days      Website             0.02       $14,885.00  6.33
# 132398  30 days   Google Ads             0.12       $11,365.00  4.65
# 158433  60 days      Website             0.12       $10,682.00  2.91
#
#            Location Language  Clicks  Impressions  Engagement_Score  \
# 31873         Miami   German     240         6355                 7
# 186549      Houston  Spanish     232         3921                 4
# 98564       Houston  Spanish     389         2837                 5
# 132398  Los Angeles  English     763         3620                 5
# 158433      Chicago  Spanish     883         5673                 9
#
#          Customer_Segment        Date
# 31873        Fashionistas  2021-04-29
# 186549       Fashionistas  2021-02-04
# 98564             Foodies  2021-01-15
# 132398  Health & Wellness  2021-09-26
# 158433            Foodies  2021-01-24

# %%
# Verificando o tamanho do dataframe (linhas, colunas)
df.shape
# Out:
# (200000, 16)

# %%
# Verificação do tipo de dados de uma coluna
df.dtypes
# Out:
# Campaign_ID           int64
# Company              object
# Campaign_Type        object
# Target_Audience      object
# Duration             object
# Channel_Used         object
# Conversion_Rate     float64
# Acquisition_Cost     object
# ROI                 float64
# Location             object
# Language             object
# Clicks                int64
# Impressions           int64
# Engagement_Score      int64
# Customer_Segment     object
# Date                 object
# dtype: object

# %% [markdown]
# ## 1.2 - Quantidade de dados nas colunas

# %%
# Vamos contar quantas observações temos em cada coluna (Verifica bastante)
df.count()
# Out:
# Campaign_ID         200000
# Company             200000
# Campaign_Type       200000
# Target_Audience     200000
# Duration            200000
# Channel_Used        200000
# Conversion_Rate     200000
# Acquisition_Cost    200000
# ROI                 200000
# Location            200000
# Language            200000
# Clicks              200000
# Impressions         200000
# Engagement_Score    200000
# Customer_Segment    200000
# Date                200000
# dtype: int64

# %% [markdown]
# ## 1.3 - Informação Detalhada do DataFrame

# %%
# Informações detalhadas do dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Campaign_ID       200000 non-null  int64
#  1   Company           200000 non-null  object
#  2   Campaign_Type     200000 non-null  object
#  3   Target_Audience   200000 non-null  object
#  4   Duration          200000 non-null  object
#  5   Channel_Used      200000 non-null  object
#  6   Conversion_Rate   200000 non-null  float64
#  7   Acquisition_Cost  200000 non-null  object
#  8   ROI               200000 non-null  float64
#  9   Location          200000 non-null  object
#  10  Language          200000 non-null  object
#  11  Clicks            200000 non-null  int64
#  12  Impressions       200000 non-null  int64
#  13  Engagement_Score  200000 non-null  int64
#  14  Customer_Segment  200000 non-null  object
#  15  Date              200000 non-null  object
# dtypes: float64(2), int64(4), object(10)
# memory usage: 24.4+ MB

# %% [markdown]
# ## 1.4 - Verifica o nome das colunas

# %%
# verificando o nome das colunas
df.columns
# Out:
# Index(['Campaign_ID', 'Company', 'Campaign_Type', 'Target_Audience',
#        'Duration', 'Channel_Used', 'Conversion_Rate', 'Acquisition_Cost',
#        'ROI', 'Location', 'Language', 'Clicks', 'Impressions',
#        'Engagement_Score', 'Customer_Segment', 'Date'],
#       dtype='object')

# %% [markdown]
# # **2 - Transformação de Dados**
#
# Verificações gerais e básicas de qualquer transformação em bases de dados, se houver os casos abaixo:
#
# * Escolher as possíveis colunas importantes para análise
# * Verificar se há colunas iguais
# * Verificar e tratar valores (observações) únicas
# * Verificar e tratar valores duplicados
# * Verificar e tratar as inconsistências (linguagem, escrita com caracteres, espaços no final e início da string e etc)
# * Verificar e tratar valores nulos (erro de digitação, não tem valor ou valor desconhecido) - pode acontecer de ter valor nulo válido dependendo do tipo de tabela
# * Tradução/Renomear
# * Transformação dos tipos adequados dos dados
# * Esse é obrigatório como sendo último a ser feito: Garantir a qualidade e integridade dos dados.

# %%
# de preferência utilizar nomes curtos e tudo em caixa baixa (padrão Soul Code)
df.rename(columns={
                   'Campaign_ID':'id',
                   'Company':'empresa',
                   'Campaign_Type':'campanha',
                   'Target_Audience':'publico_alvo',
                   'Duration':'duracao',
                   'Channel_Used':'canal',
                   'Conversion_Rate':'taxa_conversao',
                   'Acquisition_Cost':'custo',
                   'ROI':'retorno_investimento',
                   'Location':'localizacao',
                   'Language':'lingua',
                   'Clicks':'cliques',
                   'Impressions':'impressao',
                   'Engagement_Score':'engajamento',
                   'Customer_Segment':'segmento',
                   'Date':'data'

                   }, inplace = True)

# %% [markdown]
# ## 2.1 - Checando informação

# %%
# Checando alteração
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    200000 non-null  int64
#  1   empresa               200000 non-null  object
#  2   campanha              200000 non-null  object
#  3   publico_alvo          200000 non-null  object
#  4   duracao               200000 non-null  object
#  5   canal                 200000 non-null  object
#  6   taxa_conversao        200000 non-null  float64
#  7   custo                 200000 non-null  object
#  8   retorno_investimento  200000 non-null  float64
#  9   localizacao           200000 non-null  object
#  10  lingua                200000 non-null  object
#  11  cliques               200000 non-null  int64
#  12  impressao             200000 non-null  int64
#  13  engajamento           200000 non-null  int64
#  14  segmento              200000 non-null  object
#  15  data                  200000 non-null  object
# dtypes: float64(2), int64(4), object(10)
# memory usage: 24.4+ MB

# %% [markdown]
# Verificação de Valores Nulos
# * quando um código tiver mais de 30% de valores nulos, tem uma alta porcentagem de ser eliminada, mas há exceções

# %%
# Verificando valores nulos
df.isna().sum() # procura por valores nulos e soma os valores nulos
# Out:
# id                      0
# empresa                 0
# campanha                0
# publico_alvo            0
# duracao                 0
# canal                   0
# taxa_conversao          0
# custo                   0
# retorno_investimento    0
# localizacao             0
# lingua                  0
# cliques                 0
# impressao               0
# engajamento             0
# segmento                0
# data                    0
# dtype: int64

# %% [markdown]
# ## 2.2 - Porcentagem de Nulos

# %%
# Calcular a porcentagem de valores nulos em cada coluna
porcentagem_nulos = (df.isnull().sum() / len(df)) * 100

# Exibir a porcentagem de valores em cada coluna
print(round(porcentagem_nulos,1))
# Out:
# id                      0.0
# empresa                 0.0
# campanha                0.0
# publico_alvo            0.0
# duracao                 0.0
# canal                   0.0
# taxa_conversao          0.0
# custo                   0.0
# retorno_investimento    0.0
# localizacao             0.0
# lingua                  0.0
# cliques                 0.0
# impressao               0.0
# engajamento             0.0
# segmento                0.0
# data                    0.0
# dtype: float64

# %% [markdown]
# ## 2.3 - Removendo linhas

# %%
# Removendo linhas com valores NaN
df = df.dropna()

# %% [markdown]
# ##2.4 - Checagem de nulos

# %%
# Checagem se de fato os valores nulos foram eliminados
df.isna().sum()
# Out:
# id                      0
# empresa                 0
# campanha                0
# publico_alvo            0
# duracao                 0
# canal                   0
# taxa_conversao          0
# custo                   0
# retorno_investimento    0
# localizacao             0
# lingua                  0
# cliques                 0
# impressao               0
# engajamento             0
# segmento                0
# data                    0
# dtype: int64

# %% [markdown]
# ##2.5 - Verifica balanceamento

# %%
# Comando para verificar o balanceamento do dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    200000 non-null  int64
#  1   empresa               200000 non-null  object
#  2   campanha              200000 non-null  object
#  3   publico_alvo          200000 non-null  object
#  4   duracao               200000 non-null  object
#  5   canal                 200000 non-null  object
#  6   taxa_conversao        200000 non-null  float64
#  7   custo                 200000 non-null  object
#  8   retorno_investimento  200000 non-null  float64
#  9   localizacao           200000 non-null  object
#  10  lingua                200000 non-null  object
#  11  cliques               200000 non-null  int64
#  12  impressao             200000 non-null  int64
#  13  engajamento           200000 non-null  int64
#  14  segmento              200000 non-null  object
#  15  data                  200000 non-null  object
# dtypes: float64(2), int64(4), object(10)
# memory usage: 24.4+ MB

# %% [markdown]
# ## 2.6 - Verificação de alguma coluna

# %%
# Verificando se os dados são únicos na coluna (que escolher)
# Se a resposta for True: os valores são únicos
# Se a resposta for False: os valores não são únicos
df.id.is_unique
# Out:
# True

# %% [markdown]
# ##2.7 - Procurando nomes duplicados

# %%
# Encontrando as linhas duplicadas com base na coluna (video_id) mudar pelo nome de coluna que deseja
df[df.duplicated(subset='id', keep=False)]
# keep=False serve para aparecer todos os duplicados
# Out:
# Empty DataFrame
# Columns: [id, empresa, campanha, publico_alvo, duracao, canal, taxa_conversao, custo, retorno_investimento, localizacao, lingua, cliques, impressao, engajamento, segmento, data]
# Index: []

# %% [markdown]
# ## 2.8 - Verifica tamanho (linhas, colunas)

# %%
# Verificando o tamanho do dataframe (linhas, colunas)
df.shape
# Out:
# (200000, 16)

# %% [markdown]
# ##2.9 - Eliminando dados de coluna que escolher

# %%
# Eliminando dados duplicados no dataframe via coluna nome_coluna: escolher a coluna e trocar o nome
df = df.drop_duplicates(subset='id')

# %% [markdown]
# ## 2.10 - Checagem (linhas, colunas)

# %%
# Checagem
df.shape
# Out:
# (200000, 16)

# %% [markdown]
# ##2.11 - Checagem dos dados

# %%
df
# Out:
#             id              empresa      campanha publico_alvo  duracao  \
# 0            1  Innovate Industries         Email    Men 18-24  30 days
# 1            2       NexGen Systems         Email  Women 35-44  60 days
# 2            3    Alpha Innovations    Influencer    Men 25-34  30 days
# 3            4   DataTech Solutions       Display     All Ages  60 days
# 4            5       NexGen Systems         Email    Men 25-34  15 days
# ...        ...                  ...           ...          ...      ...
# 199995  199996             TechCorp       Display     All Ages  30 days
# 199996  199997   DataTech Solutions         Email    Men 25-34  15 days
# 199997  199998   DataTech Solutions  Social Media    Men 18-24  45 days
# 199998  199999  Innovate Industries    Influencer     All Ages  30 days
# 199999  200000  Innovate Industries  Social Media  Women 35-44  45 days
#
#              canal  taxa_conversao       custo  retorno_investimento  \
# 0       Google Ads            0.04  $16,174.00                  6.29
# 1       Google Ads            0.12  $11,566.00                  5.61
# 2          YouTube            0.07  $10,200.00                  7.18
# 3          YouTube            0.11  $12,724.00                  5.55
# 4          YouTube            0.05  $16,452.00                  6.50
# ...            ...             ...         ...                   ...
# 199995  Google Ads            0.06  $18,365.00                  2.84
# 199996    Facebook            0.02   $8,168.00                  4.14
# 199997     Website            0.05  $13,397.00                  3.25
# 199998     YouTube            0.10  $18,508.00                  3.86
# 199999  Google Ads            0.01  $13,835.00                  6.64
#
#         localizacao    lingua  cliques  impressao  engajamento  \
# 0           Chicago   Spanish      506       1922            6
# 1          New York    German      116       7523            7
# 2       Los Angeles    French      584       7698            1
# 3             Miami  Mandarin      217       1820            7
# 4       Los Angeles  Mandarin      379       4201            3
# ...             ...       ...      ...        ...          ...
# 199995      Chicago    German      858       5988            1
# 199996      Chicago   Spanish      228       3068            7
# 199997     New York  Mandarin      723       9548            3
# 199998      Houston    French      528       2763            1
# 199999      Chicago   Spanish      924       7287            8
#
#                    segmento        data
# 0         Health & Wellness  2021-01-01
# 1              Fashionistas  2021-01-02
# 2       Outdoor Adventurers  2021-01-03
# 3         Health & Wellness  2021-01-04
# 4         Health & Wellness  2021-01-05
# ...                     ...         ...
# 199995     Tech Enthusiasts  2021-12-07
# 199996              Foodies  2021-12-08
# 199997     Tech Enthusiasts  2021-12-09
# 199998              Foodies  2021-12-10
# 199999     Tech Enthusiasts  2021-12-11
#
# [200000 rows x 16 columns]

# %% [markdown]
# ## 2.12 - Mostrando conjunto de dados

# %%
# Mostrando conjunto de dados
df.head()
# Out:
#    id              empresa    campanha publico_alvo  duracao       canal  \
# 0   1  Innovate Industries       Email    Men 18-24  30 days  Google Ads
# 1   2       NexGen Systems       Email  Women 35-44  60 days  Google Ads
# 2   3    Alpha Innovations  Influencer    Men 25-34  30 days     YouTube
# 3   4   DataTech Solutions     Display     All Ages  60 days     YouTube
# 4   5       NexGen Systems       Email    Men 25-34  15 days     YouTube
#
#    taxa_conversao       custo  retorno_investimento  localizacao    lingua  \
# 0            0.04  $16,174.00                  6.29      Chicago   Spanish
# 1            0.12  $11,566.00                  5.61     New York    German
# 2            0.07  $10,200.00                  7.18  Los Angeles    French
# 3            0.11  $12,724.00                  5.55        Miami  Mandarin
# 4            0.05  $16,452.00                  6.50  Los Angeles  Mandarin
#
#    cliques  impressao  engajamento             segmento        data
# 0      506       1922            6    Health & Wellness  2021-01-01
# 1      116       7523            7         Fashionistas  2021-01-02
# 2      584       7698            1  Outdoor Adventurers  2021-01-03
# 3      217       1820            7    Health & Wellness  2021-01-04
# 4      379       4201            3    Health & Wellness  2021-01-05

# %% [markdown]
# ## 2.13 - Checando nome das colunas

# %%
df.columns
# Out:
# Index(['id', 'empresa', 'campanha', 'publico_alvo', 'duracao', 'canal',
#        'taxa_conversao', 'custo', 'retorno_investimento', 'localizacao',
#        'lingua', 'cliques', 'impressao', 'engajamento', 'segmento', 'data'],
#       dtype='object')

# %% [markdown]
# ##Eliminando coluna

# %%
'''
DEIXEI COMO COMENTÁRIO PARA DEIXAR O CÓDIGO DESATIVADO PARA CASO SEJA NECESSÁRIO UTILIZAR
EM UM FUTURO ARQUIVO

# Eliminando coluna desnecessárias em relação ao meu objetivo principal
df.drop([''], axis=1, inplace=True)
# axis=1 (coluna)
# axis=0 (linha)
#
'''
# Out:
# "\nDEIXEI COMO COMENTÁRIO PARA DEIXAR O CÓDIGO DESATIVADO PARA CASO SEJA NECESSÁRIO UTILIZAR\nEM UM FUTURO ARQUIVO\n\n# Eliminando coluna desnecessárias em relação ao meu objetivo principal\ndf.drop([''], axis=1, inplace=True)\n# axis=1 (coluna)\n# axis=0 (linha)\n# \n"

# %% [markdown]
# ##2.14 - Verificação se foi eliminado

# %%
df.columns
# Out:
# Index(['id', 'empresa', 'campanha', 'publico_alvo', 'duracao', 'canal',
#        'taxa_conversao', 'custo', 'retorno_investimento', 'localizacao',
#        'lingua', 'cliques', 'impressao', 'engajamento', 'segmento', 'data'],
#       dtype='object')

# %% [markdown]
# ##2.15 - Checagem das 5 primeiras linhas

# %%
# checagem
df.head()
# Out:
#    id              empresa    campanha publico_alvo  duracao       canal  \
# 0   1  Innovate Industries       Email    Men 18-24  30 days  Google Ads
# 1   2       NexGen Systems       Email  Women 35-44  60 days  Google Ads
# 2   3    Alpha Innovations  Influencer    Men 25-34  30 days     YouTube
# 3   4   DataTech Solutions     Display     All Ages  60 days     YouTube
# 4   5       NexGen Systems       Email    Men 25-34  15 days     YouTube
#
#    taxa_conversao       custo  retorno_investimento  localizacao    lingua  \
# 0            0.04  $16,174.00                  6.29      Chicago   Spanish
# 1            0.12  $11,566.00                  5.61     New York    German
# 2            0.07  $10,200.00                  7.18  Los Angeles    French
# 3            0.11  $12,724.00                  5.55        Miami  Mandarin
# 4            0.05  $16,452.00                  6.50  Los Angeles  Mandarin
#
#    cliques  impressao  engajamento             segmento        data
# 0      506       1922            6    Health & Wellness  2021-01-01
# 1      116       7523            7         Fashionistas  2021-01-02
# 2      584       7698            1  Outdoor Adventurers  2021-01-03
# 3      217       1820            7    Health & Wellness  2021-01-04
# 4      379       4201            3    Health & Wellness  2021-01-05

# %% [markdown]
# #**3 - Transformando Dados**

# %%
# Verificação do tipo dos dados
df.dtypes
# Out:
# id                        int64
# empresa                  object
# campanha                 object
# publico_alvo             object
# duracao                  object
# canal                    object
# taxa_conversao          float64
# custo                    object
# retorno_investimento    float64
# localizacao              object
# lingua                   object
# cliques                   int64
# impressao                 int64
# engajamento               int64
# segmento                 object
# data                     object
# dtype: object

# %% [markdown]
# ##3.1 - Convertendo coluna object em float

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200000 entries, 0 to 199999
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    200000 non-null  int64
#  1   empresa               200000 non-null  object
#  2   campanha              200000 non-null  object
#  3   publico_alvo          200000 non-null  object
#  4   duracao               200000 non-null  object
#  5   canal                 200000 non-null  object
#  6   taxa_conversao        200000 non-null  float64
#  7   custo                 200000 non-null  object
#  8   retorno_investimento  200000 non-null  float64
#  9   localizacao           200000 non-null  object
#  10  lingua                200000 non-null  object
#  11  cliques               200000 non-null  int64
#  12  impressao             200000 non-null  int64
#  13  engajamento           200000 non-null  int64
#  14  segmento              200000 non-null  object
#  15  data                  200000 non-null  object
# dtypes: float64(2), int64(4), object(10)
# memory usage: 25.9+ MB

# %% [markdown]
# ##3.2 - Checagem dos dados

# %%
# Checagem da transformação dos duplicados
df.dtypes
# Out:
# id                        int64
# empresa                  object
# campanha                 object
# publico_alvo             object
# duracao                  object
# canal                    object
# taxa_conversao          float64
# custo                    object
# retorno_investimento    float64
# localizacao              object
# lingua                   object
# cliques                   int64
# impressao                 int64
# engajamento               int64
# segmento                 object
# data                     object
# dtype: object

# %% [markdown]
# ##3.3 - Convertendo a coluna data_publicacao para datetime

# %%
# Convertendo a coluna data_publicacao para datetime
df['data'] = pd.to_datetime(df['data'])

# %% [markdown]
# ##3.4 - Checagem da conversão

# %%
# Checagem da conversão
# dado de datas é um "calcanhar de Aquiles" para Analista de Dados
df.dtypes
# Out:
# id                               int64
# empresa                         object
# campanha                        object
# publico_alvo                    object
# duracao                         object
# canal                           object
# taxa_conversao                 float64
# custo                           object
# retorno_investimento           float64
# localizacao                     object
# lingua                          object
# cliques                          int64
# impressao                        int64
# engajamento                      int64
# segmento                        object
# data                    datetime64[ns]
# dtype: object

# %% [markdown]
# ##3.5 - Separando dia, mes e ano em colunas diferentes

# %%
# Separando dia, mes e ano em colunas diferentes
df['ano'] = df.data.dt.year
df['mes'] = df.data.dt.month
df['dia'] = df.data.dt.day

# %% [markdown]
# ##3.6 - Checagem da separação do dia, mes e ano

# %%
#  Checagem da separação do dia, mes e ano
df.sample(5)
# Out:
#             id              empresa      campanha publico_alvo  duracao  \
# 183296  183297   DataTech Solutions  Social Media  Women 35-44  45 days
# 104904  104905             TechCorp  Social Media    Men 18-24  15 days
# 167247  167248       NexGen Systems       Display    Men 18-24  30 days
# 165492  165493  Innovate Industries       Display     All Ages  60 days
# 21675    21676  Innovate Industries         Email    Men 25-34  15 days
#
#              canal  taxa_conversao       custo  retorno_investimento  \
# 183296     YouTube            0.04  $14,033.00                  2.14
# 104904     Website            0.11  $14,014.00                  3.52
# 167247       Email            0.03   $8,716.00                  6.19
# 165492  Google Ads            0.15  $15,683.00                  3.84
# 21675    Instagram            0.12  $17,327.00                  4.90
#
#         localizacao    lingua  cliques  impressao  engajamento  \
# 183296  Los Angeles    German      440       8958            8
# 104904     New York   Spanish      615       1470           10
# 167247     New York   Spanish      648       4923            1
# 165492        Miami    German      158       2321            9
# 21675   Los Angeles  Mandarin      914       4643            8
#
#                  segmento       data   ano  mes  dia
# 183296       Fashionistas 2021-03-08  2021    3    8
# 104904            Foodies 2021-05-30  2021    5   30
# 167247   Tech Enthusiasts 2021-03-19  2021    3   19
# 165492            Foodies 2021-05-28  2021    5   28
# 21675   Health & Wellness 2021-05-21  2021    5   21

# %% [markdown]
# ## 3.7 - Verificação dos tipos de dados

# %%
# Ver os tipos de dados
df.dtypes
# não faz sentido fazer média, mediana, moda de: ano, mes e dia por esta como INT
# faz sentido ter meio ano? meio mês? meio dia? Se não faz sentido, a gente converte
# Out:
# id                               int64
# empresa                         object
# campanha                        object
# publico_alvo                    object
# duracao                         object
# canal                           object
# taxa_conversao                 float64
# custo                           object
# retorno_investimento           float64
# localizacao                     object
# lingua                          object
# cliques                          int64
# impressao                        int64
# engajamento                      int64
# segmento                        object
# data                    datetime64[ns]
# ano                              int64
# mes                              int64
# dia                              int64
# dtype: object

# %% [markdown]
# ##3.8 - Convertendo as colunas ano, mes e dia de INT para STR

# %%
# Convertendo as colunas ano, mes e dia de INT para STR
df['ano'] = df['ano'].astype(str)
df['mes'] = df['mes'].astype(str)
df['dia'] = df['dia'].astype(str)

# %% [markdown]
# ## Ver os tipos de dados

# %%
# Ver os tipos de dados
df.dtypes
# Out:
# id                               int64
# empresa                         object
# campanha                        object
# publico_alvo                    object
# duracao                         object
# canal                           object
# taxa_conversao                 float64
# custo                           object
# retorno_investimento           float64
# localizacao                     object
# lingua                          object
# cliques                          int64
# impressao                        int64
# engajamento                      int64
# segmento                        object
# data                    datetime64[ns]
# ano                             object
# mes                             object
# dia                             object
# dtype: object

# %% [markdown]
# ## 3.9 - Abrindo dataframe

# %%
# Abrindo dataframe
df.sample(5)
# Out:
#             id              empresa    campanha publico_alvo  duracao  \
# 140362  140363  Innovate Industries     Display  Women 35-44  15 days
# 149468  149469       NexGen Systems      Search     All Ages  30 days
# 49367    49368       NexGen Systems      Search     All Ages  15 days
# 127347  127348             TechCorp  Influencer    Men 18-24  15 days
# 147077  147078    Alpha Innovations       Email  Women 35-44  60 days
#
#             canal  taxa_conversao       custo  retorno_investimento  \
# 140362    Website            0.15   $6,593.00                  7.76
# 149468    YouTube            0.05   $7,514.00                  2.06
# 49367   Instagram            0.11   $9,322.00                  2.85
# 127347    Website            0.07  $15,517.00                  4.20
# 147077    Website            0.03  $16,714.00                  7.88
#
#         localizacao    lingua  cliques  impressao  engajamento  \
# 140362      Houston    German      230       6282            7
# 149468  Los Angeles    French      892       3525            4
# 49367   Los Angeles    German      102       2244            9
# 127347     New York  Mandarin      368       6598            8
# 147077      Chicago   Spanish      682       6529            5
#
#                    segmento       data   ano mes dia
# 140362    Health & Wellness 2021-07-22  2021   7  22
# 149468         Fashionistas 2021-07-03  2021   7   3
# 49367   Outdoor Adventurers 2021-04-03  2021   4   3
# 127347    Health & Wellness 2021-11-24  2021  11  24
# 147077  Outdoor Adventurers 2021-12-14  2021  12  14

# %% [markdown]
# ## 3.10 - Modificar nomes de uma coluna

# %%
# ordem alfabética da coluna, exibindo na vertical
sorted(pd.unique(df['campanha']))
# Facilita para fazer o dicionário
# Out:
# ['Display', 'Email', 'Influencer', 'Search', 'Social Media']

# %%
df['campanha'] = df['campanha'].astype(str)

# %%
df.dtypes
# Out:
# id                               int64
# empresa                         object
# campanha                        object
# publico_alvo                    object
# duracao                         object
# canal                           object
# taxa_conversao                 float64
# custo                           object
# retorno_investimento           float64
# localizacao                     object
# lingua                          object
# cliques                          int64
# impressao                        int64
# engajamento                      int64
# segmento                        object
# data                    datetime64[ns]
# ano                             object
# mes                             object
# dia                             object
# dtype: object

# %% [markdown]
# ###3.10.1 - Dicionário

# %%
# Dicionário de mapeamento para tradução de categorias
traduzindo = {'DISPLAY':'anuncios',
              'EMAIL':'email',
              'INFLUENCER':'influencer',
              'SEARCH':'buscadores',
              'SOCIAL MEDIA': 'midia',

            }

# %% [markdown]
# ## 3.11 - Substituir os valores na coluna campanha

# %%
# Substituir os valores na coluna 'palavra_chave'
df['campanha'] = df['campanha'].str.lower().replace(traduzindo)

# %% [markdown]
# ## 3.12 - Substituir os valores na coluna campanha

# %%
# Verificando
df.sample(5)
# Out:
#             id              empresa      campanha publico_alvo  duracao  \
# 176527  176528       NexGen Systems  social media  Women 25-34  30 days
# 173830  173831  Innovate Industries    influencer  Women 25-34  45 days
# 56618    56619  Innovate Industries         email  Women 25-34  15 days
# 86967    86968  Innovate Industries         email     All Ages  45 days
# 131401  131402   DataTech Solutions    influencer    Men 25-34  30 days
#
#           canal  taxa_conversao       custo  retorno_investimento  \
# 176527  YouTube            0.05  $16,909.00                  5.70
# 173830  Website            0.10  $13,640.00                  4.72
# 56618     Email            0.15   $7,672.00                  2.08
# 86967   YouTube            0.10   $8,428.00                  3.81
# 131401    Email            0.11  $18,207.00                  7.06
#
#         localizacao   lingua  cliques  impressao  engajamento  \
# 176527      Houston  English      317       3120            1
# 173830      Chicago  Spanish      106       7823            2
# 56618      New York   German      539       8115            4
# 86967       Houston   French      250       8589            3
# 131401  Los Angeles   French      552       8262            6
#
#                    segmento       data   ano mes dia
# 176527              Foodies 2021-08-21  2021   8  21
# 173830    Health & Wellness 2021-04-01  2021   4   1
# 56618      Tech Enthusiasts 2021-02-13  2021   2  13
# 86967   Outdoor Adventurers 2021-04-08  2021   4   8
# 131401     Tech Enthusiasts 2021-01-02  2021   1   2

# %% [markdown]
# #**4 - Instalação da Biblioteca Pandera**

# %%
# Instalação da biblioteca pandera
# !pip install pandera
# Out:
# Requirement already satisfied: pandera in /usr/local/lib/python3.10/dist-packages (0.18.0)
# Requirement already satisfied: multimethod in /usr/local/lib/python3.10/dist-packages (from pandera) (1.11.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from pandera) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pandera) (23.2)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from pandera) (1.5.3)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from pandera) (2.6.1)
# Requirement already satisfied: typeguard>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from pandera) (4.1.5)
# Requirement already satisfied: typing-inspect>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pandera) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from pandera) (1.14.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->pandera) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->pandera) (2023.4)
# Requirement already satisfied: typing-extensions>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from typeguard>=3.0.2->pandera) (4.9.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect>=0.6.0->pandera) (1.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->pandera) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /usr/local/lib/python3.10/dist-packages (from pydantic->pandera) (2.16.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.2.0->pandera) (1.16.0)

# %%
# importando biblioteca pandera
import pandera as pa

# %% [markdown]
# ##4.1 - Verificação dos tipos de dados

# %%
# Verificação dos tipos de dados
df.dtypes
# Out:
# id                               int64
# empresa                         object
# campanha                        object
# publico_alvo                    object
# duracao                         object
# canal                           object
# taxa_conversao                 float64
# custo                           object
# retorno_investimento           float64
# localizacao                     object
# lingua                          object
# cliques                          int64
# impressao                        int64
# engajamento                      int64
# segmento                        object
# data                    datetime64[ns]
# ano                             object
# mes                             object
# dia                             object
# dtype: object

# %%
# indice atual como uma coluna
df.reset_index()
# se quiser deixar o index, só colocar dentro do ()  inplace
# Out:
#          index      id              empresa      campanha publico_alvo  \
# 0            0       1  Innovate Industries         email    Men 18-24
# 1            1       2       NexGen Systems         email  Women 35-44
# 2            2       3    Alpha Innovations    influencer    Men 25-34
# 3            3       4   DataTech Solutions       display     All Ages
# 4            4       5       NexGen Systems         email    Men 25-34
# ...        ...     ...                  ...           ...          ...
# 199995  199995  199996             TechCorp       display     All Ages
# 199996  199996  199997   DataTech Solutions         email    Men 25-34
# 199997  199997  199998   DataTech Solutions  social media    Men 18-24
# 199998  199998  199999  Innovate Industries    influencer     All Ages
# 199999  199999  200000  Innovate Industries  social media  Women 35-44
#
#         duracao       canal  taxa_conversao       custo  retorno_investimento  \
# 0       30 days  Google Ads            0.04  $16,174.00                  6.29
# 1       60 days  Google Ads            0.12  $11,566.00                  5.61
# 2       30 days     YouTube            0.07  $10,200.00                  7.18
# 3       60 days     YouTube            0.11  $12,724.00                  5.55
# 4       15 days     YouTube            0.05  $16,452.00                  6.50
# ...         ...         ...             ...         ...                   ...
# 199995  30 days  Google Ads            0.06  $18,365.00                  2.84
# 199996  15 days    Facebook            0.02   $8,168.00                  4.14
# 199997  45 days     Website            0.05  $13,397.00                  3.25
# 199998  30 days     YouTube            0.10  $18,508.00                  3.86
# 199999  45 days  Google Ads            0.01  $13,835.00                  6.64
#
#         localizacao    lingua  cliques  impressao  engajamento  \
# 0           Chicago   Spanish      506       1922            6
# 1          New York    German      116       7523            7
# 2       Los Angeles    French      584       7698            1
# 3             Miami  Mandarin      217       1820            7
# 4       Los Angeles  Mandarin      379       4201            3
# ...             ...       ...      ...        ...          ...
# 199995      Chicago    German      858       5988            1
# 199996      Chicago   Spanish      228       3068            7
# 199997     New York  Mandarin      723       9548            3
# 199998      Houston    French      528       2763            1
# 199999      Chicago   Spanish      924       7287            8
#
#                    segmento       data   ano mes dia
# 0         Health & Wellness 2021-01-01  2021   1   1
# 1              Fashionistas 2021-01-02  2021   1   2
# 2       Outdoor Adventurers 2021-01-03  2021   1   3
# 3         Health & Wellness 2021-01-04  2021   1   4
# 4         Health & Wellness 2021-01-05  2021   1   5
# ...                     ...        ...   ...  ..  ..
# 199995     Tech Enthusiasts 2021-12-07  2021  12   7
# 199996              Foodies 2021-12-08  2021  12   8
# 199997     Tech Enthusiasts 2021-12-09  2021  12   9
# 199998              Foodies 2021-12-10  2021  12  10
# 199999     Tech Enthusiasts 2021-12-11  2021  12  11
#
# [200000 rows x 20 columns]

# %%
df.columns
# Out:
# Index(['id', 'empresa', 'campanha', 'publico_alvo', 'duracao', 'canal',
#        'taxa_conversao', 'custo', 'retorno_investimento', 'localizacao',
#        'lingua', 'cliques', 'impressao', 'engajamento', 'segmento', 'data',
#        'ano', 'mes', 'dia'],
#       dtype='object')

# %%
df.sample(5)
# Out:
#             id             empresa      campanha publico_alvo  duracao  \
# 179763  179764  DataTech Solutions       display    Men 18-24  45 days
# 53808    53809      NexGen Systems  social media    Men 18-24  15 days
# 94954    94955  DataTech Solutions    influencer     All Ages  15 days
# 177312  177313            TechCorp    influencer     All Ages  45 days
# 149421  149422      NexGen Systems  social media     All Ages  45 days
#
#              canal  taxa_conversao       custo  retorno_investimento  \
# 179763       Email            0.13   $9,622.00                  4.71
# 53808     Facebook            0.01  $15,982.00                  2.67
# 94954      Website            0.08   $7,241.00                  7.37
# 177312  Google Ads            0.08   $7,085.00                  6.25
# 149421    Facebook            0.01  $11,075.00                  7.45
#
#         localizacao    lingua  cliques  impressao  engajamento  \
# 179763      Chicago    French      453       1503            7
# 53808   Los Angeles  Mandarin      439       3677            2
# 94954   Los Angeles  Mandarin      290       9499            6
# 177312  Los Angeles    French      699       8816            3
# 149421  Los Angeles   English      795       8715            8
#
#                    segmento       data   ano mes dia
# 179763              Foodies 2021-07-03  2021   7   3
# 53808               Foodies 2021-06-03  2021   6   3
# 94954   Outdoor Adventurers 2021-02-24  2021   2  24
# 177312    Health & Wellness 2021-10-15  2021  10  15
# 149421  Outdoor Adventurers 2021-05-17  2021   5  17

# %% [markdown]
# #**5 - Esquema de Validação**
# Tipos:
# * (pa.String)
# * (pa.DateTime)
# * (pa.Int)
# * (pa.Float)

# %% [markdown]
# ## 5.1 - Verificação da coluna custos

# %%
df['custo'].head()
# Out:
# 0    $16,174.00
# 1    $11,566.00
# 2    $10,200.00
# 3    $12,724.00
# 4    $16,452.00
# Name: custo, dtype: object

# %% [markdown]
# ##5.2 - Removendo caracteres do custo
# * símbolo $
# * " , " (vírgula)
# * transformando em float

# %%
# Remove currency symbol
df['custo'] = df['custo'].str.replace('$', '')

# Substituir vírgulas por pontos na coluna 'custo'
df['custo'] = df['custo'].str.replace(',', '')

# Converter a coluna para float
df['custo'] = df['custo'].astype(float)
# Out:
# <ipython-input-56-dcb202289b69>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['custo'] = df['custo'].str.replace('$', '')

# %% [markdown]
# ##5.3 - Verificação da mudança

# %%
df['custo'].head()
# Out:
# 0    16174.0
# 1    11566.0
# 2    10200.0
# 3    12724.0
# 4    16452.0
# Name: custo, dtype: float64

# %% [markdown]
# ##5.4 - Checagem dos dados

# %%
df.sample(5)
# Out:
#             id              empresa      campanha publico_alvo  duracao  \
# 92404    92405       NexGen Systems         email     All Ages  30 days
# 128180  128181       NexGen Systems        search  Women 25-34  45 days
# 116989  116990    Alpha Innovations    influencer    Men 18-24  45 days
# 170317  170318  Innovate Industries         email    Men 18-24  30 days
# 156222  156223  Innovate Industries  social media    Men 25-34  60 days
#
#            canal  taxa_conversao    custo  retorno_investimento  localizacao  \
# 92404      Email            0.15   7150.0                  7.98      Chicago
# 128180     Email            0.12  11568.0                  2.87  Los Angeles
# 116989  Facebook            0.02   6089.0                  5.69      Houston
# 170317   YouTube            0.10   5009.0                  7.42      Houston
# 156222   YouTube            0.13  11985.0                  7.55      Chicago
#
#           lingua  cliques  impressao  engajamento             segmento  \
# 92404   Mandarin      101       9798           10              Foodies
# 128180   English      154       7487            3    Health & Wellness
# 116989    French      396       5551            1         Fashionistas
# 170317    German      671       6070            3  Outdoor Adventurers
# 156222    French      137       8546            7         Fashionistas
#
#              data   ano mes dia
# 92404  2021-03-01  2021   3   1
# 128180 2021-03-07  2021   3   7
# 116989 2021-07-09  2021   7   9
# 170317 2021-08-16  2021   8  16
# 156222 2021-01-03  2021   1   3

# %% [markdown]
# ##5.5 - Confirmação de Dados da Verificação

# %%
'''
Tipos de validação:
object=String

:pa.Column(pa.String)
:pa.Column(pa.DateTime)
:pa.Column(pa.Int)
:pa.Column(pa.Float)
'''
# Out:
# '\nTipos de validação:\nobject=String\n\n:pa.Column(pa.String)\n:pa.Column(pa.DateTime)\n:pa.Column(pa.Int)\n:pa.Column(pa.Float)\n'

# %%
schema = pa.DataFrameSchema({'id':pa.Column(pa.Int),
                             'empresa':pa.Column(pa.String),
                             'campanha':pa.Column(pa.String),
                             'publico_alvo':pa.Column(pa.String),
                             'duracao':pa.Column(pa.String),
                             'canal':pa.Column(pa.String),
                             'taxa_conversao':pa.Column(pa.Float),
                             'custo':pa.Column(pa.Float),
                             'retorno_investimento':pa.Column(pa.Float),
                             'localizacao':pa.Column(pa.String),
                             'lingua':pa.Column(pa.String),
                             'cliques':pa.Column(pa.Int),
                             'impressao':pa.Column(pa.Int),
                             'engajamento':pa.Column(pa.Int),
                             'segmento':pa.Column(pa.String),
                             'data':pa.Column(pa.DateTime),
                             'ano':pa.Column(pa.String),
                             'mes':pa.Column(pa.String),
                             'dia':pa.Column(pa.String),

                              })

# %% [markdown]
# ##5.6 - Validar o DataFrame

# %%
# Validar o DataFrame
schema.validate(df)
# Out:
#             id              empresa      campanha publico_alvo  duracao  \
# 0            1  Innovate Industries         email    Men 18-24  30 days
# 1            2       NexGen Systems         email  Women 35-44  60 days
# 2            3    Alpha Innovations    influencer    Men 25-34  30 days
# 3            4   DataTech Solutions       display     All Ages  60 days
# 4            5       NexGen Systems         email    Men 25-34  15 days
# ...        ...                  ...           ...          ...      ...
# 199995  199996             TechCorp       display     All Ages  30 days
# 199996  199997   DataTech Solutions         email    Men 25-34  15 days
# 199997  199998   DataTech Solutions  social media    Men 18-24  45 days
# 199998  199999  Innovate Industries    influencer     All Ages  30 days
# 199999  200000  Innovate Industries  social media  Women 35-44  45 days
#
#              canal  taxa_conversao    custo  retorno_investimento  \
# 0       Google Ads            0.04  16174.0                  6.29
# 1       Google Ads            0.12  11566.0                  5.61
# 2          YouTube            0.07  10200.0                  7.18
# 3          YouTube            0.11  12724.0                  5.55
# 4          YouTube            0.05  16452.0                  6.50
# ...            ...             ...      ...                   ...
# 199995  Google Ads            0.06  18365.0                  2.84
# 199996    Facebook            0.02   8168.0                  4.14
# 199997     Website            0.05  13397.0                  3.25
# 199998     YouTube            0.10  18508.0                  3.86
# 199999  Google Ads            0.01  13835.0                  6.64
#
#         localizacao    lingua  cliques  impressao  engajamento  \
# 0           Chicago   Spanish      506       1922            6
# 1          New York    German      116       7523            7
# 2       Los Angeles    French      584       7698            1
# 3             Miami  Mandarin      217       1820            7
# 4       Los Angeles  Mandarin      379       4201            3
# ...             ...       ...      ...        ...          ...
# 199995      Chicago    German      858       5988            1
# 199996      Chicago   Spanish      228       3068            7
# 199997     New York  Mandarin      723       9548            3
# 199998      Houston    French      528       2763            1
# 199999      Chicago   Spanish      924       7287            8
#
#                    segmento       data   ano mes dia
# 0         Health & Wellness 2021-01-01  2021   1   1
# 1              Fashionistas 2021-01-02  2021   1   2
# 2       Outdoor Adventurers 2021-01-03  2021   1   3
# 3         Health & Wellness 2021-01-04  2021   1   4
# 4         Health & Wellness 2021-01-05  2021   1   5
# ...                     ...        ...   ...  ..  ..
# 199995     Tech Enthusiasts 2021-12-07  2021  12   7
# 199996              Foodies 2021-12-08  2021  12   8
# 199997     Tech Enthusiasts 2021-12-09  2021  12   9
# 199998              Foodies 2021-12-10  2021  12  10
# 199999     Tech Enthusiasts 2021-12-11  2021  12  11
#
# [200000 rows x 19 columns]

# %% [markdown]
# ## 5.7 - Exportação da base de dados

# %%
# Exportação da base de dados
df.to_csv('marketing_final_v2.csv')

# %% [markdown]
# ## 5.8 - Backup

# %%
# Backup do que fizemos
dfback = df.copy

# %% [markdown]
# ##5.9 - Verificação de Dados

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200000 entries, 0 to 199999
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    200000 non-null  int64
#  1   empresa               200000 non-null  object
#  2   campanha              200000 non-null  object
#  3   publico_alvo          200000 non-null  object
#  4   duracao               200000 non-null  object
#  5   canal                 200000 non-null  object
#  6   taxa_conversao        200000 non-null  float64
#  7   custo                 200000 non-null  float64
#  8   retorno_investimento  200000 non-null  float64
#  9   localizacao           200000 non-null  object
#  10  lingua                200000 non-null  object
#  11  cliques               200000 non-null  int64
#  12  impressao             200000 non-null  int64
#  13  engajamento           200000 non-null  int64
#  14  segmento              200000 non-null  object
#  15  data                  200000 non-null  datetime64[ns]
#  16  ano                   200000 non-null  object
#  17  mes                   200000 non-null  object
#  18  dia                   200000 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(4), object(11)
# memory usage: 30.5+ MB

# %% [markdown]
# ##5.10 - Checagem dos dados

# %%
df
# Out:
#             id              empresa      campanha publico_alvo  duracao  \
# 0            1  Innovate Industries         email    Men 18-24  30 days
# 1            2       NexGen Systems         email  Women 35-44  60 days
# 2            3    Alpha Innovations    influencer    Men 25-34  30 days
# 3            4   DataTech Solutions       display     All Ages  60 days
# 4            5       NexGen Systems         email    Men 25-34  15 days
# ...        ...                  ...           ...          ...      ...
# 199995  199996             TechCorp       display     All Ages  30 days
# 199996  199997   DataTech Solutions         email    Men 25-34  15 days
# 199997  199998   DataTech Solutions  social media    Men 18-24  45 days
# 199998  199999  Innovate Industries    influencer     All Ages  30 days
# 199999  200000  Innovate Industries  social media  Women 35-44  45 days
#
#              canal  taxa_conversao    custo  retorno_investimento  \
# 0       Google Ads            0.04  16174.0                  6.29
# 1       Google Ads            0.12  11566.0                  5.61
# 2          YouTube            0.07  10200.0                  7.18
# 3          YouTube            0.11  12724.0                  5.55
# 4          YouTube            0.05  16452.0                  6.50
# ...            ...             ...      ...                   ...
# 199995  Google Ads            0.06  18365.0                  2.84
# 199996    Facebook            0.02   8168.0                  4.14
# 199997     Website            0.05  13397.0                  3.25
# 199998     YouTube            0.10  18508.0                  3.86
# 199999  Google Ads            0.01  13835.0                  6.64
#
#         localizacao    lingua  cliques  impressao  engajamento  \
# 0           Chicago   Spanish      506       1922            6
# 1          New York    German      116       7523            7
# 2       Los Angeles    French      584       7698            1
# 3             Miami  Mandarin      217       1820            7
# 4       Los Angeles  Mandarin      379       4201            3
# ...             ...       ...      ...        ...          ...
# 199995      Chicago    German      858       5988            1
# 199996      Chicago   Spanish      228       3068            7
# 199997     New York  Mandarin      723       9548            3
# 199998      Houston    French      528       2763            1
# 199999      Chicago   Spanish      924       7287            8
#
#                    segmento       data   ano mes dia
# 0         Health & Wellness 2021-01-01  2021   1   1
# 1              Fashionistas 2021-01-02  2021   1   2
# 2       Outdoor Adventurers 2021-01-03  2021   1   3
# 3         Health & Wellness 2021-01-04  2021   1   4
# 4         Health & Wellness 2021-01-05  2021   1   5
# ...                     ...        ...   ...  ..  ..
# 199995     Tech Enthusiasts 2021-12-07  2021  12   7
# 199996              Foodies 2021-12-08  2021  12   8
# 199997     Tech Enthusiasts 2021-12-09  2021  12   9
# 199998              Foodies 2021-12-10  2021  12  10
# 199999     Tech Enthusiasts 2021-12-11  2021  12  11
#
# [200000 rows x 19 columns]
