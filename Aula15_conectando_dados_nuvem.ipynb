# %% [markdown]
# # **Conectando dados ao ambiente em nuvem**
# Escola: SoulCode Academy
#
# Curso: PreparaTech - AD4
#
# Assunto: Conectando dados ao ambiente em nuvem
#
# Professor(a): Franciane Rodrigues
#
# Aluno: Vitor Kawasaki

# %% [markdown]
# ## **1 - Google Drive sem salvamento em pasta (download em máquina)**

# %% [markdown]
# ### 1.1 - Abertura de biblioteca

# %% [markdown]
# * Comando de leitura e salvamento

# %%
# Passo 1: Abertura de biblioteca
from google.colab import files

# %% [markdown]
# ### 1.2 - Fazendo upload

# %%
# Passo 2: Fazendo o upload do nosso arquivo do computador
upload = files.upload()
# o upload fica na pasta arquivos na lateral esquerda, abaixo de secrets(desenho chave)
# o arquivo fica somente em tempo de execução
# Out:
#      <input type="file" id="files-fa504fd5-6abf-4885-b0bf-7832433eb416" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fa504fd5-6abf-4885-b0bf-7832433eb416">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### 1.3 - Importe a biblioteca Pandas

# %% [markdown]
# * Extração e carregamento

# %%
# Passo 3: Abrindo a biblioteca para EXTRAÇÃO do nosso dataset
# biblioteca de manipulação, transformação de dados. ETL, que significa Extract, Transform, Load
import pandas as pd

# %% [markdown]
# ### 1.4 - Faça a extração

# %%
# Passo 4: Extração da Informação via pandas
# transformar dataset em dataframe
df = pd.read_csv('/content/youtube_bruto.csv') # dataframe (df) recebe leitura em pandas do tipo csv.
# encontra a pasta na pasta arquivos, clica no 3 pontinhos, botão direito do mouse e
# selecionar "copiar caminho" e colar no pd.read_csv('colar_arquivo')

# %% [markdown]
# ### 1.5 - Mostrando/Exibindo o dataframe

# %%
# Passo 5: mostrando o dataframe
df
# Out:
#       Unnamed: 0                                              Title  \
# 0              0  Apple Pay Is Killing the Physical Wallet After...
# 1              1                    The most EXPENSIVE thing I own.
# 2              2                 My New House Gaming Setup is SICK!
# 3              3  Petrol Vs Liquid Nitrogen | Freezing Experimen...
# 4              4                     Best Back to School Tech 2022!
# ...          ...                                                ...
# 1876        1876                 Should You Learn Machine Learning?
# 1877        1877            Todos podemos aprender Machine learning
# 1878        1878  Andrew Ng: Deep Learning, Education, and Real-...
# 1879        1879                          What is Machine Learning?
# 1880        1880                   Don&#39;t learn machine learning
#
#          Video ID Published At           Keyword    Likes  Comments      Views
# ...

# %% [markdown]
# ### 1.6 - Faça o tratamento da tabela

# %%
# Passo 6: Consideraremos que o tratamento foi realizado

# %% [markdown]
# ### 1.7 - Exportação ao Google Drive

# %%
# Passo 7: Exportação ao Google Drive
df.to_csv('youtube_tratado.csv')

# %% [markdown]
# ### 1.8 - Faça o Download

# %%
# Passo 8: Faça o download do seu arquivo tratado na sua máquina

# %% [markdown]
# ## 2 - Google Drive com salvamento em pasta

# %% [markdown]
# ### 2.1 - Abertura do Google Drive

# %%
# Passo 1: Comando para abertura do Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 2.2 - Abrindo a biblioteca para extração do nosso dataset

# %%
# Passo 2: Abrindo a biblioteca para EXTRAÇÃO do nosso dataset
import pandas as pd

# %% [markdown]
# ### 2.3 - Extração da informação via Pandas

# %%
# Passo 3: Extração da Informação via pandas
# transformar dataset em dataframe
df = pd.read_csv('/content/drive/MyDrive/PreparaTech/youtube/youtube_bruto.csv')

# %% [markdown]
# ### 2.4 -  Mostrando/Exibindo o dataframe

# %%
# Passo 4: mostrando/observando o dataframe
df
# Out:
#       Unnamed: 0                                              Title  \
# 0              0  Apple Pay Is Killing the Physical Wallet After...
# 1              1                    The most EXPENSIVE thing I own.
# 2              2                 My New House Gaming Setup is SICK!
# 3              3  Petrol Vs Liquid Nitrogen | Freezing Experimen...
# 4              4                     Best Back to School Tech 2022!
# ...          ...                                                ...
# 1876        1876                 Should You Learn Machine Learning?
# 1877        1877            Todos podemos aprender Machine learning
# 1878        1878  Andrew Ng: Deep Learning, Education, and Real-...
# 1879        1879                          What is Machine Learning?
# 1880        1880                   Don&#39;t learn machine learning
#
#          Video ID Published At           Keyword    Likes  Comments      Views
# ...

# %% [markdown]
# ### 2.5 - Faça as transformações necessárias

# %%
# Passo 5: Nesse passo será feito no futuro a transformação de dados via pandas

# %% [markdown]
# ### 2.6 - Exportação ao Google Drive

# %%
# Passo 6: Exportação ao Google Drive.
# copia o atalho do drive e muda o nome de bruto para tratado
df.to_csv('/content/drive/MyDrive/PreparaTech/youtube/youtube_tratado.csv')

# %% [markdown]
# ## 3 - Opcional: BigQuery

# %% [markdown]
# ### 3.1 - Autenticando o usuário no Google Colab

# %%
# Passo 1: Autenticando o usuário no Google Colab
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %% [markdown]
# ### 3.2 - Importando a biblioteca cliente do Google BigQuery em um ambiente Python

# %%
# Passo 2: Importando a biblioteca cliente do Google BigQuery em um ambiente Python
from google.cloud import bigquery
import pandas as pd
import pandas_gbq

# %% [markdown]
# ### 3.3 - Informando o nome do projeto

# %%
# Passo 3: Informando o nome do projeto
# pegar o ID do BigQuery
project_id = 'aulabigquery01'
client = bigquery.Client(project=project_id)

# %%
'''
SELECT * FROM `aulabigquery01.youtube.youtube_bruto`
'''
# Out:
# '\nSELECT * FROM `aulabigquery01.youtube.youtube_bruto`\n'

# %% [markdown]
# ### 3.4 - Realizando a conexão da consulta com a BigQuery

# %%
# Passo 4: Realizando a conexão da consulta com a BigQuery
query_extracao = client.query('''SELECT * FROM `aulabigquery01.youtube.youtube_bruto`''')

# %% [markdown]
# ### 3.5 - Lendo o conjunto de dados

# %%
# Passo 5: Lendo o conjunto de dados
query_extracao
# Out:
# QueryJob<project=aulabigquery01, location=US, id=da332f8e-733a-4c2a-9337-f97a3ee72635>

# %% [markdown]
# ### 3.6 - Convertendo a nossa consulta em uma dataframe

# %%
# Passo 6: Convertendo a nossa consulta em um Dataframe
df = query_extracao.to_dataframe()

# %% [markdown]
# ### 3.7 - Ver o dataframe

# %%
# Passo 7: Ver o dataframe
df
# Out:
#       int64_field_0                                              Title  \
# 0               744                                  Jacquees - B.E.D.
# 1               745                          Jacquees - B.E.D. (Audio)
# 2               746            J. Holiday - Bed (Official Music Video)
# 3               747                Nicki Minaj - Bed ft. Ariana Grande
# 4               748  Joel Corry x RAYE x David Guetta - BED [Offici...
# ...             ...                                                ...
# 1876           1876                 Should You Learn Machine Learning?
# 1877           1877            Todos podemos aprender Machine learning
# 1878           1878  Andrew Ng: Deep Learning, Education, and Real-...
# 1879           1879                          What is Machine Learning?
# 1880           1880                   Don&#39;t learn machine learning
#
#          Video_ID Published_At           Keyword      Likes  Comments  \
# ...

# %% [markdown]
# ### 3.8 - Fase de transformação dos dados via Pandas

# %%
# Passo 8: Fase de transformação dos dados via pandas

# %% [markdown]
# ### 3.9 - Ir ao BigQuery, criar tabela em branco e copiar ID

# %%
# Passo 9: é necessário ir na BigQuery e criar uma tabela em branco e copiar o ID

# %% [markdown]
# * ID da tabela que criou do BigQuery

# %%
'''
aulabigquery01.youtube.youtube_tratado2
'''
# Out:
# '\naulabigquery01.youtube.youtube_tratado2\n'

# %% [markdown]
# ### 3.10 - Coloque o caminho da tabela do BigQuery onde carregará seus dados

# %%
# Passo 10: Coloque o caminho da tabela do BigQuery onde você carregará seus dados
table_id = 'aulabigquery01.youtube.youtube_tratado2'

# %% [markdown]
# ### 3.11 - Carregando dados na BigQuery

# %%
# Passo 11: Carregando dados na BigQuery
pandas_gbq.to_gbq(df, table_id, project_id=project_id) # transformando dataframe
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 645.48it/s]
